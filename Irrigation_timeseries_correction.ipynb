# %%
from data_processing import *
from correction_algorithms import *
from figures_plotting import *
# Out:
# /apps/brussel/RL8/skylake/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Load the historical and future data. For the future data we focus only on ssp2_rcp26_gfdl as an example.

# %%
hist_gridded_data = process_files('/user/brussel/105/vsc10535/SocioHydroLayers/input/sector_demand_link/processed/yearly_format/irrigation/ensemble_mean/', 'ensemble_mean_withd_irrig_')
# Out:
# A xarray.Dataset corresponding to the data in the given path was succesfully generated.

# %%
future_gridded_data = process_files('/user/brussel/105/vsc10535/SocioHydroLayers/input/sector_demand_future_link/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/irrigation/', 'twdirr_m3_per_day_')
# Out:
# A xarray.Dataset corresponding to the data in the given path was succesfully generated.

# %% [markdown]
# ## Load the countries and US states masks.

# %%
mask_countries = read_mask_file('/user/brussel/105/vsc10535/SocioHydroLayers/input/support_data/updated_global_mask_v2.nc')
mask_US_states = read_mask_file('/user/brussel/105/vsc10535/SocioHydroLayers/input/support_data/updated_US_mask_v2.nc')
# Out:
# A numpy.ndarray corresponding to the mask file provided was succesfully generated.
# A numpy.ndarray corresponding to the mask file provided was succesfully generated.

# %% [markdown]
# ## Initialize supporting data

# %%
countries_names, countries_indices, states_names, states_indices = define_countries_and_states_names_and_indices()
# Out:
# Countries and US states names were initialized. Country index 177 corresponds to gridcells not attributed to any country. State code 51 corresponds to gridcells not attributed to any US state.

# %% [markdown]
# ## Initialize xarray.DataArray's to contain the countries or US states historical and future time-series.

# %%
hist_countries_timeseries = xr.DataArray(np.zeros((len(countries_indices), 480)), dims=('country', 'time'),
                                                 coords={'country': countries_indices, 'time': pd.date_range('1971-01', periods=480, freq='M')})

future_countries_timeseries = xr.DataArray(np.zeros((len(countries_indices), 1092)), dims=('country', 'time'),
                                             coords={'country': countries_indices, 'time': pd.date_range('2010-01', periods=1092, freq='M')})

hist_US_states_timeseries = xr.DataArray(np.zeros((len(states_indices), 480)), dims=('US_states', 'time'),
                                                 coords={'US_states': states_indices, 'time': pd.date_range('1971-01', periods=480, freq='M')})

future_US_states_timeseries = xr.DataArray(np.zeros((len(states_indices), 1092)), dims=('US_states', 'time'),
                                             coords={'US_states': states_indices, 'time': pd.date_range('2010-01', periods=1092, freq='M')})

# %% [markdown]
# ## Compute national and US states time-series.

# %%
compute_national_or_state_monthly_timeseries(hist_gridded_data, hist_countries_timeseries, mask_countries)
# Out:
# Provided data covers the years 1971--2010.
# Begin computing the historical countries time-series.
# Calculation completed at 25%
# Calculation completed at 50%
# Calculation completed at 75%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(hist_gridded_data, hist_US_states_timeseries, mask_US_states)
# Out:
# Provided data covers the years 1971--2010.
# Begin computing the historical US states time-series.
# Calculation completed at 25%
# Calculation completed at 50%
# Calculation completed at 75%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(future_gridded_data, future_countries_timeseries, mask_countries)
# Out:
# Provided data covers the years 2010--2100.
# Begin computing the future countries time-series.
# Calculation completed at 24%
# Calculation completed at 48%
# Calculation completed at 72%
# Calculation completed at 96%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(future_gridded_data, future_US_states_timeseries, mask_US_states)
# Out:
# Provided data covers the years 2010--2100.
# Begin computing the future US states time-series.
# Calculation completed at 24%
# Calculation completed at 48%
# Calculation completed at 72%
# Calculation completed at 96%
# Calculation completed at 100%

# %% [markdown]
# ## Plot countries and US states timeseries:

# %%
plot_countries_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/country_level/", hist_countries_timeseries, future_countries_timeseries, "Irrigation", countries_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/country_level/ directory.

# %%
plot_US_states_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/US_state_level", hist_US_states_timeseries, future_US_states_timeseries, "Irrigation", states_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/US_state_level directory.

# %% [markdown]
# ## Visually inspect the national timeseries plots:
# Main issues found are drops/jumps at the transition between past and future periods (year 2010-2011), and missmatch of the seasonality pattern/amplitude.
#
# A suitable correction method is applied, which will shift the future timeseries to match historical values for year 2010, while adjusting future seasonality pattern/amplitude for continuity with historical timeseries, while preserving trends in the seasonality change projected in the future dataset.

# %% [markdown]
# ## Initialize the xarray.DataArray's to contain the countries or US states corrected future time-series.

# %%
dims = ('country', 'time')
coords = {
    'country': future_countries_timeseries.country.values,
    'time': future_countries_timeseries.time.values
}

dims_states = ('US_states', 'time')
coords_states = {
    'US_states': future_US_states_timeseries.US_states.values,
    'time': future_US_states_timeseries.time.values
}


corrected_future_countries_timeseries = xr.DataArray(data=np.zeros((178, 1092)), dims=dims, coords=coords)
corrected_future_US_states_timeseries = xr.DataArray(data=np.zeros((52, 1092)), dims=dims_states, coords=coords_states)

years_historical = pd.date_range(start='1971-01', periods=hist_countries_timeseries.sizes['time'], freq='M')
years_future = pd.date_range(start='2010-01', periods=future_countries_timeseries.sizes['time'], freq='M')

# %% [markdown]
# ## Apply the necessary correction algorithm:

# %%
apply_the_correction_algorithm_at_country_and_US_state_level_v3(countries_names, states_names, hist_countries_timeseries, future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, corrected_future_countries_timeseries, corrected_future_US_states_timeseries, years_future, sector="Irrigation", use_bias_adjustment=True, apply_amplitude_correction=True, number_of_years_to_use_for_amplitude_reference_N=5, apply_iterative_rescaling_to_correct_for_negative_values=True, minimum_future_ratio=0.1)
# Out:
# Fiji
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Calculation completed at 0%
# Tanzania
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# W. Sahara
# Negative values found, iterative rescaling applied.
# Historical middle point is zero, skipping this country.
# Final bias adjustment was completed.
# Canada
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Alaska
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Alabama
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Arkansas
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Arizona
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# California
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Colorado
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Connecticut
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# District of Columbia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Delaware
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Florida
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Georgia
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Hawaii
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Iowa
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 47.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -11.94%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 30.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.53%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 20.32%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.08%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.55%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.54%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.84%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.38%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.35%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.96%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.99%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.93%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.73%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.54%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.62%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.11%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Idaho
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Illinois
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Indiana
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 23.85%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.96%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 16.47%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.12%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.67%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.92%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.1%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.13%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.53%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.51%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.13%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.83%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.47%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.62%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.84%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Kansas
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Kentucky
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Louisiana
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 59.17%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -14.79%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 35.62%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.91%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 23.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.89%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 16.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.07%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.89%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.32%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.08%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.52%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.46%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.12%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.3%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.82%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.44%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.61%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.31%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Massachusetts
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Maryland
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Maine
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Michigan
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Minnesota
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 26.01%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 17.81%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.45%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 12.57%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.14%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.26%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.57%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.2%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.89%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.64%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.66%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.96%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.45%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Missouri
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Mississippi
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Montana
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# North Carolina
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# North Dakota
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Nebraska
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.08%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.2%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.8%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.38%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.59%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# New Hampshire
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# New Jersey
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# New Mexico
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Nevada
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# New York
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Ohio
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Oklahoma
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Oregon
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Pennsylvania
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Rhode Island
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 32.35%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.09%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 21.69%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.42%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 15.13%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.78%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.8%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.96%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.43%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.06%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.13%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.78%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.58%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.73%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.23%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# South Carolina
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# South Dakota
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Tennessee
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.86%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.47%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.79%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.31%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.86%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.96%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.86%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.71%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.53%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Texas
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Utah
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Virginia
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 842.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 606.8%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 430.1%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 297.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 198.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 123.64%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 67.73%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -16.93%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 39.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -9.83%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 25.63%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.41%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 17.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.39%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 12.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.1%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.92%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.23%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.49%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.62%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.19%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.52%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.88%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.61%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.65%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.94%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.43%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Vermont
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Washington
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Wisconsin
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.29%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.57%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.55%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.4%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.85%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.35%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.98%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.74%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.19%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.55%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.63%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# West Virginia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Wyoming
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# No correction applied to gridcells outside the regionmask US states boundaries (state code 51).
# Kazakhstan
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Uzbekistan
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Papua New Guinea
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Indonesia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Argentina
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Chile
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Dem. Rep. Congo
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Somalia
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 24.32%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.08%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 16.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.19%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.88%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.97%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.14%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.59%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.15%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.85%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.52%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.63%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.87%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Kenya
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Sudan
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Chad
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Haiti
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Dominican Rep.
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Russia
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Bahamas
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Falkland Is.
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Norway
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Greenland
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Fr. S. Antarctic Lands
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Timor-Leste
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# South Africa
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Lesotho
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 42.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -10.55%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 27.19%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.8%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 18.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 13.05%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.26%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.34%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.8%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.99%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.25%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.92%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.68%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.02%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.51%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.51%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.0%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Mexico
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Uruguay
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Brazil
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Bolivia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Peru
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Colombia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Panama
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Costa Rica
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Nicaragua
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Honduras
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# El Salvador
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Guatemala
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Belize
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Venezuela
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Guyana
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Suriname
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# France
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Ecuador
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Calculation completed at 24%
# Puerto Rico
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Jamaica
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Cuba
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Zimbabwe
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Botswana
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Namibia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Senegal
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Mali
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Mauritania
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Benin
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Niger
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 368.65%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 252.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 165.09%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 99.66%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -24.92%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 50.76%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -12.69%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 32.06%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 21.74%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.44%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 15.31%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.83%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.76%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.06%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.49%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.42%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.11%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.31%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.83%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.48%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.62%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.87%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.37%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Nigeria
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Cameroon
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Togo
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Ghana
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Côte d'Ivoire
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Guinea
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Guinea-Bissau
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Liberia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# ...
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.13%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.03%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.93%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.48%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.09%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.81%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.6%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.78%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Eritrea
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Japan
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Paraguay
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Yemen
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Saudi Arabia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Antarctica
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# N. Cyprus
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Cyprus
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Morocco
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Egypt
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Libya
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Ethiopia
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Djibouti
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Somaliland
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Uganda
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Rwanda
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Bosnia and Herz.
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# North Macedonia
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 19.25%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.81%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 13.51%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.38%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.42%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.02%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.76%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.14%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.29%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.79%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.95%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.81%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.09%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.52%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.05%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Serbia
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 101.02%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 50.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -12.69%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 31.63%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.91%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 21.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.31%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.79%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.63%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.91%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.39%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.11%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.03%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.04%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.76%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.25%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.17%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Montenegro
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1407.25%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1030.44%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 747.83%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 535.87%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 376.9%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 257.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 168.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 101.19%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 50.9%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -12.72%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 31.7%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.92%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 21.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.32%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.64%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.91%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.59%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.4%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.11%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.03%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.04%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.76%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.17%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Kosovo
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Final bias adjustment was completed.
# Trinidad and Tobago
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# S. Sudan
# No negative values found, no rescaling needed.
# Final bias adjustment was completed.
# Calculation completed at 98%
# No correction applied to gridcells outside the regionmask country boundaries (country code 177).
# Future countries and US states timeseries are corrected. The updated values can be found in the provided input xarray.DataArray's.

# %% [markdown]
# ## Plot corrected national and US states timeseries:

# %%
plot_countries_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/country_level/", hist_countries_timeseries, future_countries_timeseries, corrected_future_countries_timeseries, "Irrigation", countries_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/country_level/ directory.

# %%
plot_US_states_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/US_state_level", hist_US_states_timeseries, future_US_states_timeseries, corrected_future_US_states_timeseries, "Irrigation", states_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/US_state_level directory.

# %% [markdown]
# ## Plot orriginal and corrected global water withdrawal time-series:

# %%
plot_global_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level", hist_countries_timeseries, future_countries_timeseries, corrected_future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, corrected_future_US_states_timeseries, "Irrigation", countries_names, states_names)
# Out:
# Global plot has been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level directory.

# %%
plot_global_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level", hist_countries_timeseries, future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, "Irrigation", countries_names, states_names)
# Out:
# Global plot has been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level directory.

# %% [markdown]
# ## Visually inspect corrected national, US states and global timeseries:
#
# Through visual inspection we can confirm a perfect harmonization between the past and future datasets.

# %% [markdown]
# # Check for any negative values

# %%
# Check for negative values in corrected_future_countries_timeseries
check_negative_values(corrected_future_countries_timeseries, countries_names, entity_type="country")

# Check for negative values in corrected_future_US_states_timeseries
check_negative_values(corrected_future_US_states_timeseries, states_names, entity_type="US_states")
# Out:
# No negative values found in Country dataset.
# No negative values found in Us_states dataset.

# %% [markdown]
# # Save the time-series as .csv files

# %%
import xarray as xr
import pandas as pd

# Assuming the following DataArrays are already defined:
# hist_countries_timeseries: xarray.DataArray with dims (country: 178, time: 480)
# corrected_future_countries_timeseries: xarray.DataArray with dims (country: 178, time: 1092)
# countries_names: dictionary mapping indices to country names

# Concatenate the historical and future time-series along the time dimension
combined_timeseries = xr.concat([hist_countries_timeseries, corrected_future_countries_timeseries], dim='time')

# Loop over each country and save the corresponding time-series to a CSV file
for country_index in range(len(countries_names)):
    # Extract the data for the current country
    country_data = combined_timeseries.sel(country=country_index)
    
    # Convert to DataFrame
    country_df = country_data.to_dataframe(name='value').reset_index()
    
    # Map the country index to its name
    country_name = countries_names[country_index]
    country_df['country'] = country_name
    
    # Save to CSV with the country name as the filename
    filename = "./csv_files_of_countries_and_us_states_timeseries/irrigation_" + f"{country_name}_timeseries.csv"
    country_df.to_csv(filename, index=False)
    
    print(f"Saved {filename}")
# Out:
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Fiji_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Tanzania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_W. Sahara_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Canada_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_United States of America_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kazakhstan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Uzbekistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Papua New Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Indonesia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Argentina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Chile_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Dem. Rep. Congo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Somalia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kenya_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Sudan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Chad_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Haiti_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Dominican Rep._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Russia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Bahamas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Falkland Is._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Norway_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Greenland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Fr. S. Antarctic Lands_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Timor-Leste_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_South Africa_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Lesotho_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Mexico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Uruguay_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Brazil_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Bolivia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Peru_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Colombia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Panama_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Costa Rica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Nicaragua_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Honduras_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_El Salvador_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Guatemala_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Belize_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Venezuela_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Guyana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Suriname_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_France_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Ecuador_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Puerto Rico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Jamaica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Cuba_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Zimbabwe_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Botswana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Namibia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Senegal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Mali_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Mauritania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Benin_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Niger_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Nigeria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Cameroon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Togo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Ghana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Côte d'Ivoire_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Guinea-Bissau_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Liberia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Sierra Leone_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Burkina Faso_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Central African Rep._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Congo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Gabon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Eq. Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Zambia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Malawi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Mozambique_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_eSwatini_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Angola_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Burundi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Israel_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Lebanon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Madagascar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Palestine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Gambia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Tunisia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Algeria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Jordan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_United Arab Emirates_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Qatar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kuwait_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Iraq_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Oman_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Vanuatu_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Cambodia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Thailand_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Laos_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Myanmar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Vietnam_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_North Korea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_South Korea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Mongolia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_India_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Bangladesh_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Bhutan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Nepal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Pakistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Afghanistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Tajikistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kyrgyzstan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Turkmenistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Iran_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Syria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Armenia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Sweden_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Belarus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Ukraine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Poland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Austria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Hungary_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Moldova_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Romania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Lithuania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Latvia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Estonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Germany_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Bulgaria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Greece_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Turkey_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Albania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Croatia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Switzerland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Luxembourg_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Belgium_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Netherlands_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Portugal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Spain_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Ireland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_New Caledonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Solomon Is._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_New Zealand_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Australia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Sri Lanka_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_China_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Taiwan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Italy_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Denmark_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_United Kingdom_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Iceland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Azerbaijan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Georgia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Philippines_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Malaysia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Brunei_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Slovenia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Finland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Slovakia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Czechia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Eritrea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Japan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Paraguay_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Yemen_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Saudi Arabia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Antarctica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_N. Cyprus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Cyprus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Morocco_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Egypt_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Libya_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Ethiopia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Djibouti_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Somaliland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Uganda_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Rwanda_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Bosnia and Herz._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_North Macedonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Serbia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Montenegro_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kosovo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Trinidad and Tobago_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_S. Sudan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Not a regionmask country_timeseries.csv

# %%
import xarray as xr
import pandas as pd

# Assuming the following DataArrays are already defined:
# hist_US_states_timeseries: xarray.DataArray with dims (state: N, time: 480)
# corrected_future_US_states_timeseries: xarray.DataArray with dims (state: N, time: 1092)
# states_names: dictionary mapping indices to state names

# Concatenate the historical and future time-series along the time dimension
combined_timeseries = xr.concat([hist_US_states_timeseries, corrected_future_US_states_timeseries], dim='time')

# Loop over each state and save the corresponding time-series to a CSV file
for state_index in range(len(states_names)):
    # Extract the data for the current state
    state_data = combined_timeseries.sel(US_states=state_index)
    
    # Convert to DataFrame
    state_df = state_data.to_dataframe(name='value').reset_index()
    
    # Map the state index to its name
    state_name = states_names[state_index]
    state_df['US_states'] = state_name
    
    # Save to CSV with the state name as the filename
    filename = "./csv_files_of_countries_and_us_states_timeseries/irrigation_" + f"{state_name}_timeseries.csv"
    state_df.to_csv(filename, index=False)
    
    print(f"Saved {filename}")
# Out:
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Alaska_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Alabama_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Arkansas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Arizona_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_California_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Colorado_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Connecticut_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_District of Columbia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Delaware_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Florida_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Georgia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Hawaii_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Iowa_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Idaho_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Illinois_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Indiana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kansas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Kentucky_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Louisiana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Massachusetts_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Maryland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Maine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Michigan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Minnesota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Missouri_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Mississippi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Montana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_North Carolina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_North Dakota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Nebraska_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_New Hampshire_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_New Jersey_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_New Mexico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Nevada_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_New York_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Ohio_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Oklahoma_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Oregon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Pennsylvania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Rhode Island_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_South Carolina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_South Dakota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Tennessee_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Texas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Utah_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Virginia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Vermont_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Washington_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Wisconsin_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_West Virginia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Wyoming_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/irrigation_Not a regionmask state_timeseries.csv

# %% [markdown]
# # Downscale the national and US states data

# %% [markdown]
# After correcting the time-series at natioanal level, we should update the individual gridcells values accordingly. To do so, we apply the same gridcells weights as in the original future water use dataset to perform the spatial downscaling of the new national time series.

# %%
path_to_save_corrected_gridded_data = "/user/brussel/105/vsc10535/SocioHydroLayers/input/sector_demand_future_link/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/irrigation"
downscale_future_corrected_national_and_US_states_timeseries_to_gridded_format_and_save_it(future_gridded_data, path_to_save_corrected_gridded_data, mask_countries, states_indices, mask_US_states, countries_indices, corrected_future_countries_timeseries, corrected_future_US_states_timeseries, "total_withdrawal_irrigation", "twdirrig")
# Out:
# Year completed: 2010
# Year completed: 2020
# Year completed: 2030
# Year completed: 2040
# Year completed: 2050
# Year completed: 2060
# Year completed: 2070
# Year completed: 2080
# Year completed: 2090
# Year completed: 2100
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2010.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2011.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2012.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2013.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2014.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2015.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2016.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2017.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2018.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2019.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2020.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2021.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2022.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2023.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2024.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2025.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2026.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2027.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2028.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2029.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2030.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2031.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2032.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2033.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2034.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2035.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2036.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2037.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2038.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2039.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2040.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2041.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2042.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2043.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2044.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2045.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2046.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2047.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2048.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2049.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2050.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2051.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2052.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2053.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2054.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2055.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2056.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2057.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2058.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2059.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2060.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2061.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2062.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2063.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2064.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2065.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2066.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2067.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2068.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2069.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2070.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2071.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2072.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2073.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2074.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2075.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2076.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2077.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2078.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2079.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2080.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2081.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2082.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2083.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2084.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2085.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2086.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2087.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2088.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2089.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2090.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2091.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2092.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2093.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2094.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2095.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2096.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2097.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2098.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2099.nc
# Saved twdirrig_m3_per_day_with_corrected_national_time_series_2100.nc

# %% [markdown]
# # Plot the spatial consistency:

# %%
# Historical data processing
historical_directory = '/user/brussel/105/vsc10535/SocioHydroLayers/input/sector_demand_link/processed/yearly_format/irrigation/ensemble_mean/'
historical_pattern = "ensemble_mean_"
historical_data = process_files_annual_average(historical_directory, historical_pattern)

# Future data processing
future_directory = '/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/irrigation/'
future_pattern = 'twdirr_m3_per_day'
future_data = process_files_annual_average(future_directory, future_pattern)

# Corrected future data processing
corrected_future_pattern = 'twdirrig_m3_per_day_with_corrected_national_time_series'
corrected_future_data = process_files_annual_average(future_directory, corrected_future_pattern)
# Out:
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.

# %%
def plot_water_withdrawal_changes(historical_data, original_future_data, corrected_future_data, variable_name_hist, variable_name_future, variable_name_for_the_title, path_save_plot):
    map_proj = ccrs.Robinson(central_longitude=0)
    
    # Create a figure with 1 row and 2 columns
    fig, axes = plt.subplots(1, 2, figsize=(20, 10), subplot_kw={'projection': map_proj})
    
    # First figure: Change for 2010/2011 with the original data
    ax1 = axes[0]
    ww_2010 = historical_data.sel(time='2010')[variable_name_hist][0]
    ww_2011_original = original_future_data.sel(time='2011')[variable_name_future][0]
    delta_original = (ww_2011_original - ww_2010) / ww_2010 * 100
    
    ax1.axis('off')
    ax1.coastlines(color='lightgray', linewidth=0.5)
    delta_original.plot(ax=ax1, cbar_kwargs={'fraction': 0.02, 'pad': 0.04, 'extend': 'both'}, cmap='RdBu', vmin=-100, vmax=100, transform=ccrs.PlateCarree(), add_colorbar=True, add_labels=False)
    ax1.set_title(f'$\Delta$ {variable_name_for_the_title} 2010-2011 (Original) (%)', loc='right', fontsize=20)
    
    # Second figure: Change for 2010/2011 with the corrected data
    ax2 = axes[1]
    ww_2011_corrected = corrected_future_data.sel(time='2011')[variable_name_future][0]
    delta_corrected = (ww_2011_corrected - ww_2010) / ww_2010 * 100
    
    ax2.axis('off')
    ax2.coastlines(color='lightgray', linewidth=0.5)
    delta_corrected.plot(ax=ax2, cbar_kwargs={'fraction': 0.02, 'pad': 0.04, 'extend': 'both'}, cmap='RdBu', vmin=-100, vmax=100, transform=ccrs.PlateCarree(), add_colorbar=True, add_labels=False)
    ax2.set_title(f'$\Delta$ {variable_name_for_the_title} 2010-2011 (Corrected) (%)', loc='right', fontsize=20)
    
    fig.tight_layout()
    plt.savefig(path_save_plot, format='pdf')

# %%
path_save_plot = "/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/spatial_consistency_maps/relative_change_in_irrigation_water_withdrawal_original.pdf"
plot_water_withdrawal_changes(historical_data, future_data, corrected_future_data, "h08_withd_irrig", "total_withdrawal_irrigation", "Irrigation Withdrawal", path_save_plot)

# %%
future_data
# Out:
# <xarray.Dataset>
# Dimensions:                      (lon: 720, lat: 280, time: 91)
# Coordinates:
#   * lon                          (lon) float64 -179.8 -179.2 ... 179.2 179.8
#   * lat                          (lat) float64 -55.75 -55.25 ... 83.25 83.75
#   * time                         (time) datetime64[ns] 2010-12-31 ... 2100-12-31
# Data variables:
#     total_withdrawal_irrigation  (time, lat, lon) float64 nan nan ... nan nan
