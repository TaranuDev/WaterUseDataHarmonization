# %%
from data_processing import *
from correction_algorithms import *
from figures_plotting import *
# Out:
# /apps/brussel/RL8/skylake/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Load the historical and future data. For the future data we focus only on ssp2_rcp26_gfdl as an example.

# %%
hist_gridded_data = process_files('/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand/processed/yearly_format/electric/', 'withd_elec_')
# Out:
# A xarray.Dataset corresponding to the data in the given path was succesfully generated.

# %%
future_gridded_data = process_files('/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/electric/', 'twdelec_m3_per_day_2')
# Out:
# A xarray.Dataset corresponding to the data in the given path was succesfully generated.

# %% [markdown]
# ## Load the countries and US states masks.

# %%
mask_countries = read_mask_file('/user/brussel/105/vsc10535/SocioHydroLayers/input/support_data/updated_global_mask_v2.nc')
mask_US_states = read_mask_file('/user/brussel/105/vsc10535/SocioHydroLayers/input/support_data/updated_US_mask_v2.nc')
# Out:
# A numpy.ndarray corresponding to the mask file provided was succesfully generated.
# A numpy.ndarray corresponding to the mask file provided was succesfully generated.

# %% [markdown]
# ## Initialize supporting data

# %%
countries_names, countries_indices, states_names, states_indices = define_countries_and_states_names_and_indices()
# Out:
# Countries and US states names were initialized. Country index 177 corresponds to gridcells not attributed to any country. State code 51 corresponds to gridcells not attributed to any US state.

# %% [markdown]
# ## Initialize xarray.DataArray's to contain the countries or US states historical and future time-series.

# %%
hist_countries_timeseries = xr.DataArray(np.zeros((len(countries_indices), 480)), dims=('country', 'time'),
                                                 coords={'country': countries_indices, 'time': pd.date_range('1971-01', periods=480, freq='M')})

future_countries_timeseries = xr.DataArray(np.zeros((len(countries_indices), 1092)), dims=('country', 'time'),
                                             coords={'country': countries_indices, 'time': pd.date_range('2010-01', periods=1092, freq='M')})

hist_US_states_timeseries = xr.DataArray(np.zeros((len(states_indices), 480)), dims=('US_states', 'time'),
                                                 coords={'US_states': states_indices, 'time': pd.date_range('1971-01', periods=480, freq='M')})

future_US_states_timeseries = xr.DataArray(np.zeros((len(states_indices), 1092)), dims=('US_states', 'time'),
                                             coords={'US_states': states_indices, 'time': pd.date_range('2010-01', periods=1092, freq='M')})

# %% [markdown]
# ## Compute national and US states time-series.

# %%
compute_national_or_state_monthly_timeseries(hist_gridded_data, hist_countries_timeseries, mask_countries)
# Out:
# Provided data covers the years 1971--2010.
# Begin computing the historical countries time-series.
# Calculation completed at 25%
# Calculation completed at 50%
# Calculation completed at 75%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(hist_gridded_data, hist_US_states_timeseries, mask_US_states)
# Out:
# Provided data covers the years 1971--2010.
# Begin computing the historical US states time-series.
# Calculation completed at 25%
# Calculation completed at 50%
# Calculation completed at 75%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(future_gridded_data, future_countries_timeseries, mask_countries)
# Out:
# Provided data covers the years 2010--2100.
# Begin computing the future countries time-series.
# Calculation completed at 24%
# Calculation completed at 48%
# Calculation completed at 72%
# Calculation completed at 96%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(future_gridded_data, future_US_states_timeseries, mask_US_states)
# Out:
# Provided data covers the years 2010--2100.
# Begin computing the future US states time-series.
# Calculation completed at 24%
# Calculation completed at 48%
# Calculation completed at 72%
# Calculation completed at 96%
# Calculation completed at 100%

# %% [markdown]
# ## Plot countries and US states timeseries:

# %%
plot_countries_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/country_level/", hist_countries_timeseries, future_countries_timeseries, "Electric", countries_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/country_level/ directory.

# %%
plot_US_states_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/US_state_level", hist_US_states_timeseries, future_US_states_timeseries, "Electric", states_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/US_state_level directory.

# %% [markdown]
# ## Visually inspect the national timeseries plots:
# Main issues found are drops/jumps at the transition between past and future periods (year 2010-2011), and missmatch of the seasonality pattern/amplitude.
#
# A suitable correction method is applied, which will shift the future timeseries to match historical values for year 2010, while adjusting future seasonality pattern/amplitude for continuity with historical timeseries, while preserving trends in the seasonality change projected in the future dataset.

# %% [markdown]
# ## Initialize the xarray.DataArray's to contain the countries or US states corrected future time-series.

# %%
dims = ('country', 'time')
coords = {
    'country': future_countries_timeseries.country.values,
    'time': future_countries_timeseries.time.values
}

dims_states = ('US_states', 'time')
coords_states = {
    'US_states': future_US_states_timeseries.US_states.values,
    'time': future_US_states_timeseries.time.values
}


corrected_future_countries_timeseries = xr.DataArray(data=np.zeros((178, 1092)), dims=dims, coords=coords)
corrected_future_US_states_timeseries = xr.DataArray(data=np.zeros((52, 1092)), dims=dims_states, coords=coords_states)

years_historical = pd.date_range(start='1971-01', periods=hist_countries_timeseries.sizes['time'], freq='M')
years_future = pd.date_range(start='2010-01', periods=future_countries_timeseries.sizes['time'], freq='M')

# %% [markdown]
# ## Apply the necessary correction algorithm:

# %%
apply_the_correction_algorithm_at_country_and_US_state_level_v3(countries_names, states_names, hist_countries_timeseries, future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, corrected_future_countries_timeseries, corrected_future_US_states_timeseries, years_future, sector="Electric", use_bias_adjustment=True, apply_amplitude_correction=True, number_of_years_to_use_for_amplitude_reference_N=1, apply_iterative_rescaling_to_correct_for_negative_values=True, minimum_future_ratio=0.1)
# Out:
# Fiji
# No negative values found, no rescaling needed.
# Calculation completed at 0%
# Tanzania
# No negative values found, no rescaling needed.
# W. Sahara
# No negative values found, no rescaling needed.
# Canada
# No negative values found, no rescaling needed.
# Alaska
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 57.38%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -14.34%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 34.87%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.72%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 23.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.79%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 16.05%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.85%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.25%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.06%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.51%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.44%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.11%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.28%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.82%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.44%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.61%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.31%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Alabama
# No negative values found, no rescaling needed.
# Arkansas
# No negative values found, no rescaling needed.
# Arizona
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 315.13%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 211.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 133.86%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 75.59%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -18.9%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 42.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -10.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 27.47%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.87%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 18.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.69%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 13.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.31%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.52%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.38%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.93%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.73%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.09%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.27%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.76%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.94%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.79%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.08%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.52%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.05%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# California
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2722.23%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2016.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1487.98%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1091.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 793.71%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 570.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 403.19%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 277.66%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 183.52%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 112.91%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 59.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -14.99%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 36.14%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -9.04%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 23.94%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.98%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 16.59%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.15%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.8%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.95%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.53%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.13%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.6%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.15%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.85%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.63%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.89%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Colorado
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 345.46%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 234.57%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 151.4%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 89.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -22.26%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 47.38%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -11.85%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 30.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.54%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 20.48%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.12%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.6%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.59%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.89%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.39%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.03%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.06%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.77%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.29%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.57%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.71%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Connecticut
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 82.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -20.6%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 45.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -11.32%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 29.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.27%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 19.84%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.96%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.01%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.09%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.52%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.37%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.84%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.43%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.36%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.0%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.75%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# District of Columbia
# No negative values found, no rescaling needed.
# Delaware
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 177.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 107.97%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 56.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -14.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 34.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.55%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 22.75%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.69%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 15.78%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.95%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.81%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.11%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.03%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.92%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.48%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.09%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.81%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.6%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.78%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Florida
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 135.04%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 76.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -19.14%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 42.97%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -10.74%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 27.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.93%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 18.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.74%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 13.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.34%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.61%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.4%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.0%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.75%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.29%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.81%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.95%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.83%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.71%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.11%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.53%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Georgia
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 12.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.06%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.86%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.22%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.48%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.62%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.78%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.19%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.89%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.64%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.66%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.97%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.47%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Hawaii
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 53.19%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -13.3%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 32.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.21%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 21.92%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.48%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 15.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.81%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.85%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.71%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.84%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.96%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.73%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.43%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.05%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.78%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.31%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.58%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Iowa
# No negative values found, no rescaling needed.
# Idaho
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7353.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5490.04%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4092.53%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3044.4%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2258.3%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1668.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1226.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 894.91%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 646.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 459.64%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 319.73%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 214.79%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 136.1%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 77.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -19.27%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 42.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -10.74%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 27.6%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.9%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 18.8%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.7%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 13.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.3%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 9.47%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.37%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.88%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.72%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.04%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.26%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.93%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.75%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.69%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.05%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.51%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.52%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.02%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Illinois
# No negative values found, no rescaling needed.
# Indiana
# No negative values found, no rescaling needed.
# Kansas
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 24.66%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.17%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 17.06%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.26%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 12.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.03%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.76%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.19%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.6%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.18%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.5%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.88%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.61%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.65%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.95%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.44%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Kentucky
# No negative values found, no rescaling needed.
# Louisiana
# No negative values found, no rescaling needed.
# Massachusetts
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 351.91%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 239.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 155.0%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 91.71%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -22.93%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 48.17%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -12.04%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 30.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 20.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.18%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.56%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.46%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.61%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.62%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.9%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.6%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.4%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.04%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.09%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.77%
# ...
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Saudi Arabia
# No negative values found, no rescaling needed.
# Antarctica
# No negative values found, no rescaling needed.
# N. Cyprus
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 368.77%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 251.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 163.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 97.76%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -24.44%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 49.43%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -12.36%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 30.96%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.74%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 20.83%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.21%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.63%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.37%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.59%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.51%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.88%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.49%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.37%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.04%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.99%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.75%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.65%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.15%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Cyprus
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 425.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 293.91%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 195.43%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 121.57%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 66.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -16.55%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 38.69%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -9.67%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 25.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.32%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 17.36%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.34%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 12.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.07%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.21%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.42%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.61%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.71%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.18%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.48%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.87%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.58%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.92%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.41%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Morocco
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.39%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.85%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.46%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.36%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.06%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.01%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.76%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.57%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.71%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Egypt
# No negative values found, no rescaling needed.
# Libya
# No negative values found, no rescaling needed.
# Ethiopia
# No negative values found, no rescaling needed.
# Djibouti
# Negative values found, iterative rescaling applied.
# Historical middle point is zero, skipping this country.
# Somaliland
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 289.27%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 191.96%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 118.97%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 64.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -16.06%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 37.86%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -9.46%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 24.81%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.2%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 17.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.27%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 12.07%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.02%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.69%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.17%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.33%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.58%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.65%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.16%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.43%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.86%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.89%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.38%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Uganda
# No negative values found, no rescaling needed.
# Rwanda
# No negative values found, no rescaling needed.
# Bosnia and Herz.
# No negative values found, no rescaling needed.
# North Macedonia
# No negative values found, no rescaling needed.
# Serbia
# No negative values found, no rescaling needed.
# Montenegro
# No negative values found, no rescaling needed.
# Kosovo
# No negative values found, no rescaling needed.
# Trinidad and Tobago
# No negative values found, no rescaling needed.
# S. Sudan
# No negative values found, no rescaling needed.
# Calculation completed at 98%
# No correction applied to gridcells outside the regionmask country boundaries (country code 177).
# Future countries and US states timeseries are corrected. The updated values can be found in the provided input xarray.DataArray's.

# %% [markdown]
# ## Plot corrected national and US states timeseries:

# %%
plot_countries_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/country_level/", hist_countries_timeseries, future_countries_timeseries, corrected_future_countries_timeseries, "Electric", countries_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/country_level/ directory.

# %%
plot_US_states_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/US_state_level", hist_US_states_timeseries, future_US_states_timeseries, corrected_future_US_states_timeseries, "Electric", states_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/US_state_level directory.

# %% [markdown]
# ## Plot orriginal and corrected global water withdrawal time-series:

# %%
plot_global_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level", hist_countries_timeseries, future_countries_timeseries, corrected_future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, corrected_future_US_states_timeseries, "Electric", countries_names, states_names)
# Out:
# Global plot has been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level directory.

# %%
plot_global_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level", hist_countries_timeseries, future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, "Electric", countries_names, states_names)
# Out:
# Global plot has been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level directory.

# %% [markdown]
# ## Visually inspect corrected national, US states and global timeseries:
#
# Through visual inspection we can confirm a perfect harmonization between the past and future datasets.

# %% [markdown]
# # Check for any negative values

# %%
# Check for negative values in corrected_future_countries_timeseries
check_negative_values(corrected_future_countries_timeseries, countries_names, entity_type="country")

# Check for negative values in corrected_future_US_states_timeseries
check_negative_values(corrected_future_US_states_timeseries, states_names, entity_type="US_states")
# Out:
# Negative values found in Greenland
# No negative values found in Us_states dataset.

# %% [markdown]
# # Save the time-series as .csv files

# %%
import xarray as xr
import pandas as pd

# Assuming the following DataArrays are already defined:
# hist_countries_timeseries: xarray.DataArray with dims (country: 178, time: 480)
# corrected_future_countries_timeseries: xarray.DataArray with dims (country: 178, time: 1092)
# countries_names: dictionary mapping indices to country names

# Concatenate the historical and future time-series along the time dimension
combined_timeseries = xr.concat([hist_countries_timeseries, corrected_future_countries_timeseries], dim='time')

# Loop over each country and save the corresponding time-series to a CSV file
for country_index in range(len(countries_names)):
    # Extract the data for the current country
    country_data = combined_timeseries.sel(country=country_index)
    
    # Convert to DataFrame
    country_df = country_data.to_dataframe(name='value').reset_index()
    
    # Map the country index to its name
    country_name = countries_names[country_index]
    country_df['country'] = country_name
    
    # Save to CSV with the country name as the filename
    filename = "./csv_files_of_countries_and_us_states_timeseries/electric_" + f"{country_name}_timeseries.csv"
    country_df.to_csv(filename, index=False)
    
    print(f"Saved {filename}")
# Out:
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Fiji_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Tanzania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_W. Sahara_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Canada_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_United States of America_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kazakhstan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Uzbekistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Papua New Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Indonesia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Argentina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Chile_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Dem. Rep. Congo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Somalia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kenya_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Sudan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Chad_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Haiti_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Dominican Rep._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Russia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Bahamas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Falkland Is._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Norway_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Greenland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Fr. S. Antarctic Lands_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Timor-Leste_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_South Africa_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Lesotho_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Mexico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Uruguay_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Brazil_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Bolivia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Peru_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Colombia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Panama_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Costa Rica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Nicaragua_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Honduras_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_El Salvador_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Guatemala_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Belize_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Venezuela_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Guyana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Suriname_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_France_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Ecuador_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Puerto Rico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Jamaica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Cuba_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Zimbabwe_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Botswana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Namibia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Senegal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Mali_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Mauritania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Benin_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Niger_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Nigeria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Cameroon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Togo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Ghana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Côte d'Ivoire_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Guinea-Bissau_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Liberia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Sierra Leone_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Burkina Faso_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Central African Rep._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Congo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Gabon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Eq. Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Zambia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Malawi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Mozambique_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_eSwatini_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Angola_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Burundi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Israel_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Lebanon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Madagascar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Palestine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Gambia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Tunisia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Algeria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Jordan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_United Arab Emirates_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Qatar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kuwait_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Iraq_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Oman_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Vanuatu_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Cambodia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Thailand_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Laos_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Myanmar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Vietnam_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_North Korea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_South Korea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Mongolia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_India_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Bangladesh_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Bhutan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Nepal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Pakistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Afghanistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Tajikistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kyrgyzstan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Turkmenistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Iran_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Syria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Armenia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Sweden_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Belarus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Ukraine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Poland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Austria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Hungary_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Moldova_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Romania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Lithuania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Latvia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Estonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Germany_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Bulgaria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Greece_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Turkey_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Albania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Croatia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Switzerland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Luxembourg_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Belgium_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Netherlands_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Portugal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Spain_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Ireland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_New Caledonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Solomon Is._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_New Zealand_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Australia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Sri Lanka_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_China_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Taiwan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Italy_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Denmark_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_United Kingdom_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Iceland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Azerbaijan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Georgia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Philippines_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Malaysia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Brunei_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Slovenia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Finland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Slovakia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Czechia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Eritrea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Japan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Paraguay_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Yemen_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Saudi Arabia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Antarctica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_N. Cyprus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Cyprus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Morocco_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Egypt_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Libya_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Ethiopia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Djibouti_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Somaliland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Uganda_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Rwanda_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Bosnia and Herz._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_North Macedonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Serbia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Montenegro_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kosovo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Trinidad and Tobago_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_S. Sudan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Not a regionmask country_timeseries.csv

# %%
import xarray as xr
import pandas as pd

# Assuming the following DataArrays are already defined:
# hist_US_states_timeseries: xarray.DataArray with dims (state: N, time: 480)
# corrected_future_US_states_timeseries: xarray.DataArray with dims (state: N, time: 1092)
# states_names: dictionary mapping indices to state names

# Concatenate the historical and future time-series along the time dimension
combined_timeseries = xr.concat([hist_US_states_timeseries, corrected_future_US_states_timeseries], dim='time')

# Loop over each state and save the corresponding time-series to a CSV file
for state_index in range(len(states_names)):
    # Extract the data for the current state
    state_data = combined_timeseries.sel(US_states=state_index)
    
    # Convert to DataFrame
    state_df = state_data.to_dataframe(name='value').reset_index()
    
    # Map the state index to its name
    state_name = states_names[state_index]
    state_df['US_states'] = state_name
    
    # Save to CSV with the state name as the filename
    filename = "./csv_files_of_countries_and_us_states_timeseries/electric_" + f"{state_name}_timeseries.csv"
    state_df.to_csv(filename, index=False)
    
    print(f"Saved {filename}")
# Out:
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Alaska_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Alabama_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Arkansas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Arizona_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_California_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Colorado_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Connecticut_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_District of Columbia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Delaware_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Florida_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Georgia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Hawaii_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Iowa_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Idaho_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Illinois_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Indiana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kansas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Kentucky_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Louisiana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Massachusetts_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Maryland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Maine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Michigan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Minnesota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Missouri_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Mississippi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Montana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_North Carolina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_North Dakota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Nebraska_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_New Hampshire_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_New Jersey_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_New Mexico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Nevada_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_New York_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Ohio_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Oklahoma_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Oregon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Pennsylvania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Rhode Island_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_South Carolina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_South Dakota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Tennessee_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Texas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Utah_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Virginia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Vermont_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Washington_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Wisconsin_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_West Virginia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Wyoming_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/electric_Not a regionmask state_timeseries.csv

# %% [markdown]
# # Downscale the national and US states data

# %% [markdown]
# After correcting the time-series at natioanal level, we should update the individual gridcells values accordingly. To do so, we apply the same gridcells weights as in the original future water use dataset to perform the spatial downscaling of the new national time series.

# %%
path_to_save_corrected_gridded_data = "/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/electric"
downscale_future_corrected_national_and_US_states_timeseries_to_gridded_format_and_save_it(future_gridded_data, path_to_save_corrected_gridded_data, mask_countries, states_indices, mask_US_states, countries_indices, corrected_future_countries_timeseries, corrected_future_US_states_timeseries, "total_withdrawal_electric", "twdelec")
# Out:
# Year completed: 2010
# Year completed: 2020
# Year completed: 2030
# Year completed: 2040
# Year completed: 2050
# Year completed: 2060
# Year completed: 2070
# Year completed: 2080
# Year completed: 2090
# Year completed: 2100
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2010.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2011.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2012.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2013.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2014.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2015.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2016.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2017.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2018.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2019.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2020.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2021.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2022.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2023.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2024.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2025.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2026.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2027.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2028.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2029.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2030.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2031.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2032.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2033.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2034.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2035.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2036.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2037.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2038.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2039.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2040.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2041.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2042.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2043.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2044.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2045.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2046.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2047.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2048.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2049.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2050.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2051.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2052.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2053.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2054.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2055.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2056.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2057.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2058.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2059.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2060.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2061.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2062.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2063.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2064.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2065.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2066.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2067.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2068.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2069.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2070.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2071.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2072.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2073.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2074.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2075.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2076.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2077.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2078.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2079.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2080.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2081.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2082.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2083.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2084.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2085.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2086.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2087.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2088.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2089.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2090.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2091.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2092.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2093.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2094.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2095.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2096.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2097.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2098.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2099.nc
# Saved twdelec_m3_per_day_with_corrected_national_time_series_2100.nc

# %% [markdown]
# # Plot the spatial consistency:

# %%
# Historical data processing
historical_directory = '/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand/processed/yearly_format/electric/'
historical_pattern = 'withd_elec_'
historical_data = process_files_annual_average(historical_directory, historical_pattern)

# Future data processing
future_directory = '/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/electric/'
future_pattern = 'twdelec_m3_per_day_2'
future_data = process_files_annual_average(future_directory, future_pattern)

# Corrected future data processing
corrected_future_pattern = 'twdelec_m3_per_day_with_corrected_national_time_series_'
corrected_future_data = process_files_annual_average(future_directory, corrected_future_pattern)
# Out:
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.

# %%
def plot_water_withdrawal_changes(historical_data, original_future_data, corrected_future_data, variable_name_hist, variable_name_future, variable_name_for_the_title, path_save_plot):
    map_proj = ccrs.Robinson(central_longitude=0)
    
    # Create a figure with 1 row and 2 columns
    fig, axes = plt.subplots(1, 2, figsize=(20, 10), subplot_kw={'projection': map_proj})
    
    # First figure: Change for 2010/2011 with the original data
    ax1 = axes[0]
    ww_2010 = historical_data.sel(time='2010')[variable_name_hist][0]
    ww_2011_original = original_future_data.sel(time='2011')[variable_name_future][0]
    delta_original = (ww_2011_original - ww_2010) / ww_2010 * 100
    
    ax1.axis('off')
    ax1.coastlines(color='lightgray', linewidth=0.5)
    delta_original.plot(ax=ax1, cbar_kwargs={'fraction': 0.02, 'pad': 0.04, 'extend': 'both'}, cmap='RdBu', vmin=-100, vmax=100, transform=ccrs.PlateCarree(), add_colorbar=True, add_labels=False)
    ax1.set_title(f'$\Delta$ {variable_name_for_the_title} 2010-2011 (Original) (%)', loc='right', fontsize=20)
    
    # Second figure: Change for 2010/2011 with the corrected data
    ax2 = axes[1]
    ww_2011_corrected = corrected_future_data.sel(time='2011')[variable_name_future][0]
    delta_corrected = (ww_2011_corrected - ww_2010) / ww_2010 * 100
    
    ax2.axis('off')
    ax2.coastlines(color='lightgray', linewidth=0.5)
    delta_corrected.plot(ax=ax2, cbar_kwargs={'fraction': 0.02, 'pad': 0.04, 'extend': 'both'}, cmap='RdBu', vmin=-100, vmax=100, transform=ccrs.PlateCarree(), add_colorbar=True, add_labels=False)
    ax2.set_title(f'$\Delta$ {variable_name_for_the_title} 2010-2011 (Corrected) (%)', loc='right', fontsize=20)
    
    fig.tight_layout()
    plt.savefig(path_save_plot, format='pdf')

# %%
path_save_plot = "/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/spatial_consistency_maps/relative_change_in_electric_water_withdrawal_original.pdf"
plot_water_withdrawal_changes(historical_data, future_data, corrected_future_data, "withd_elec", "total_withdrawal_electric", "Electric Withdrawal", path_save_plot)
