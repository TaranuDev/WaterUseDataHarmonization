# %%
from data_processing import *
from correction_algorithms import *
from figures_plotting import *
# Out:
# /apps/brussel/RL8/skylake/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Load the historical and future data. For the future data we focus only on ssp2_rcp26_gfdl as an example.

# %%
hist_gridded_data = process_files('/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand/processed/yearly_format/livestock/', 'withdrawal_livestock_m3_per_day_')
# Out:
# A xarray.Dataset corresponding to the data in the given path was succesfully generated.

# %%
future_gridded_data = process_files('/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/livestock/', 'twdliv_m3_per_day_2')
# Out:
# A xarray.Dataset corresponding to the data in the given path was succesfully generated.

# %% [markdown]
# ## Load the countries and US states masks.

# %%
mask_countries = read_mask_file('/user/brussel/105/vsc10535/SocioHydroLayers/input/support_data/updated_global_mask_v2.nc')
mask_US_states = read_mask_file('/user/brussel/105/vsc10535/SocioHydroLayers/input/support_data/updated_US_mask_v2.nc')
# Out:
# A numpy.ndarray corresponding to the mask file provided was succesfully generated.
# A numpy.ndarray corresponding to the mask file provided was succesfully generated.

# %% [markdown]
# ## Initialize supporting data

# %%
countries_names, countries_indices, states_names, states_indices = define_countries_and_states_names_and_indices()
# Out:
# Countries and US states names were initialized. Country index 177 corresponds to gridcells not attributed to any country. State code 51 corresponds to gridcells not attributed to any US state.

# %% [markdown]
# ## Initialize xarray.DataArray's to contain the countries or US states historical and future time-series.

# %%
hist_countries_timeseries = xr.DataArray(np.zeros((len(countries_indices), 480)), dims=('country', 'time'),
                                                 coords={'country': countries_indices, 'time': pd.date_range('1971-01', periods=480, freq='M')})

future_countries_timeseries = xr.DataArray(np.zeros((len(countries_indices), 1092)), dims=('country', 'time'),
                                             coords={'country': countries_indices, 'time': pd.date_range('2010-01', periods=1092, freq='M')})

hist_US_states_timeseries = xr.DataArray(np.zeros((len(states_indices), 480)), dims=('US_states', 'time'),
                                                 coords={'US_states': states_indices, 'time': pd.date_range('1971-01', periods=480, freq='M')})

future_US_states_timeseries = xr.DataArray(np.zeros((len(states_indices), 1092)), dims=('US_states', 'time'),
                                             coords={'US_states': states_indices, 'time': pd.date_range('2010-01', periods=1092, freq='M')})

# %% [markdown]
# ## Compute national and US states time-series.

# %%
compute_national_or_state_monthly_timeseries(hist_gridded_data, hist_countries_timeseries, mask_countries)
# Out:
# Provided data covers the years 1971--2010.
# Begin computing the historical countries time-series.
# Calculation completed at 25%
# Calculation completed at 50%
# Calculation completed at 75%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(hist_gridded_data, hist_US_states_timeseries, mask_US_states)
# Out:
# Provided data covers the years 1971--2010.
# Begin computing the historical US states time-series.
# Calculation completed at 25%
# Calculation completed at 50%
# Calculation completed at 75%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(future_gridded_data, future_countries_timeseries, mask_countries)
# Out:
# Provided data covers the years 2010--2100.
# Begin computing the future countries time-series.
# Calculation completed at 24%
# Calculation completed at 48%
# Calculation completed at 72%
# Calculation completed at 96%
# Calculation completed at 100%

# %%
compute_national_or_state_monthly_timeseries(future_gridded_data, future_US_states_timeseries, mask_US_states)
# Out:
# Provided data covers the years 2010--2100.
# Begin computing the future US states time-series.
# Calculation completed at 24%
# Calculation completed at 48%
# Calculation completed at 72%
# Calculation completed at 96%
# Calculation completed at 100%

# %% [markdown]
# ## Plot countries and US states timeseries:

# %%
plot_countries_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/country_level/", hist_countries_timeseries, future_countries_timeseries, "Livestock", countries_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/country_level/ directory.

# %%
plot_US_states_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/US_state_level", hist_US_states_timeseries, future_US_states_timeseries, "Livestock", states_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_no_correction/US_state_level directory.

# %% [markdown]
# ## Visually inspect the national timeseries plots:
# Main issues found are drops/jumps at the transition between past and future periods (year 2010-2011), and missmatch of the seasonality pattern/amplitude.
#
# A suitable correction method is applied, which will shift the future timeseries to match historical values for year 2010, while adjusting future seasonality pattern/amplitude for continuity with historical timeseries, while preserving trends in the seasonality change projected in the future dataset.

# %% [markdown]
# ## Initialize the xarray.DataArray's to contain the countries or US states corrected future time-series.

# %%
dims = ('country', 'time')
coords = {
    'country': future_countries_timeseries.country.values,
    'time': future_countries_timeseries.time.values
}

dims_states = ('US_states', 'time')
coords_states = {
    'US_states': future_US_states_timeseries.US_states.values,
    'time': future_US_states_timeseries.time.values
}


corrected_future_countries_timeseries = xr.DataArray(data=np.zeros((178, 1092)), dims=dims, coords=coords)
corrected_future_US_states_timeseries = xr.DataArray(data=np.zeros((52, 1092)), dims=dims_states, coords=coords_states)

years_historical = pd.date_range(start='1971-01', periods=hist_countries_timeseries.sizes['time'], freq='M')
years_future = pd.date_range(start='2010-01', periods=future_countries_timeseries.sizes['time'], freq='M')

# %% [markdown]
# ## Apply the necessary correction algorithm:

# %%
apply_the_correction_algorithm_at_country_and_US_state_level_v3(countries_names, states_names, hist_countries_timeseries, future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, corrected_future_countries_timeseries, corrected_future_US_states_timeseries, years_future, sector="Livestock", use_bias_adjustment=True, apply_amplitude_correction=False, number_of_years_to_use_for_amplitude_reference_N=1, apply_iterative_rescaling_to_correct_for_negative_values=True, minimum_future_ratio=0.1)
# Out:
# Fiji
# No negative values found, no rescaling needed.
# Calculation completed at 0%
# Tanzania
# No negative values found, no rescaling needed.
# W. Sahara
# No negative values found, no rescaling needed.
# Canada
# No negative values found, no rescaling needed.
# Alaska
# No negative values found, no rescaling needed.
# Alabama
# No negative values found, no rescaling needed.
# Arkansas
# No negative values found, no rescaling needed.
# Arizona
# No negative values found, no rescaling needed.
# California
# No negative values found, no rescaling needed.
# Colorado
# No negative values found, no rescaling needed.
# Connecticut
# No negative values found, no rescaling needed.
# District of Columbia
# No negative values found, no rescaling needed.
# Delaware
# No negative values found, no rescaling needed.
# Florida
# No negative values found, no rescaling needed.
# Georgia
# No negative values found, no rescaling needed.
# Hawaii
# No negative values found, no rescaling needed.
# Iowa
# No negative values found, no rescaling needed.
# Idaho
# No negative values found, no rescaling needed.
# Illinois
# No negative values found, no rescaling needed.
# Indiana
# No negative values found, no rescaling needed.
# Kansas
# No negative values found, no rescaling needed.
# Kentucky
# No negative values found, no rescaling needed.
# Louisiana
# No negative values found, no rescaling needed.
# Massachusetts
# No negative values found, no rescaling needed.
# Maryland
# No negative values found, no rescaling needed.
# Maine
# No negative values found, no rescaling needed.
# Michigan
# No negative values found, no rescaling needed.
# Minnesota
# No negative values found, no rescaling needed.
# Missouri
# No negative values found, no rescaling needed.
# Mississippi
# No negative values found, no rescaling needed.
# Montana
# No negative values found, no rescaling needed.
# North Carolina
# No negative values found, no rescaling needed.
# North Dakota
# No negative values found, no rescaling needed.
# Nebraska
# No negative values found, no rescaling needed.
# New Hampshire
# No negative values found, no rescaling needed.
# New Jersey
# No negative values found, no rescaling needed.
# New Mexico
# No negative values found, no rescaling needed.
# Nevada
# No negative values found, no rescaling needed.
# New York
# No negative values found, no rescaling needed.
# Ohio
# No negative values found, no rescaling needed.
# Oklahoma
# No negative values found, no rescaling needed.
# Oregon
# No negative values found, no rescaling needed.
# Pennsylvania
# No negative values found, no rescaling needed.
# Rhode Island
# No negative values found, no rescaling needed.
# South Carolina
# No negative values found, no rescaling needed.
# South Dakota
# No negative values found, no rescaling needed.
# Tennessee
# No negative values found, no rescaling needed.
# Texas
# No negative values found, no rescaling needed.
# Utah
# No negative values found, no rescaling needed.
# Virginia
# No negative values found, no rescaling needed.
# Vermont
# No negative values found, no rescaling needed.
# Washington
# No negative values found, no rescaling needed.
# Wisconsin
# No negative values found, no rescaling needed.
# West Virginia
# No negative values found, no rescaling needed.
# Wyoming
# No negative values found, no rescaling needed.
# No correction applied to gridcells outside the regionmask US states boundaries (state code 51).
# Kazakhstan
# No negative values found, no rescaling needed.
# Uzbekistan
# No negative values found, no rescaling needed.
# Papua New Guinea
# No negative values found, no rescaling needed.
# Indonesia
# No negative values found, no rescaling needed.
# Argentina
# No negative values found, no rescaling needed.
# Chile
# No negative values found, no rescaling needed.
# Dem. Rep. Congo
# No negative values found, no rescaling needed.
# Somalia
# No negative values found, no rescaling needed.
# Kenya
# No negative values found, no rescaling needed.
# Sudan
# No negative values found, no rescaling needed.
# Chad
# No negative values found, no rescaling needed.
# Haiti
# No negative values found, no rescaling needed.
# Dominican Rep.
# No negative values found, no rescaling needed.
# Russia
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 53.19%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -13.3%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 32.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -8.21%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 21.92%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.48%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 15.24%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.81%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.85%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.71%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.85%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.96%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.73%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.43%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.22%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.05%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.12%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.78%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.31%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.58%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.72%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.21%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Bahamas
# No negative values found, no rescaling needed.
# Falkland Is.
# No negative values found, no rescaling needed.
# Norway
# No negative values found, no rescaling needed.
# Greenland
# No negative values found, no rescaling needed.
# Fr. S. Antarctic Lands
# No negative values found, no rescaling needed.
# Timor-Leste
# No negative values found, no rescaling needed.
# South Africa
# No negative values found, no rescaling needed.
# Lesotho
# No negative values found, no rescaling needed.
# Mexico
# No negative values found, no rescaling needed.
# Uruguay
# No negative values found, no rescaling needed.
# Brazil
# No negative values found, no rescaling needed.
# Bolivia
# No negative values found, no rescaling needed.
# Peru
# No negative values found, no rescaling needed.
# Colombia
# No negative values found, no rescaling needed.
# Panama
# No negative values found, no rescaling needed.
# Costa Rica
# No negative values found, no rescaling needed.
# Nicaragua
# No negative values found, no rescaling needed.
# Honduras
# No negative values found, no rescaling needed.
# El Salvador
# No negative values found, no rescaling needed.
# Guatemala
# No negative values found, no rescaling needed.
# Belize
# No negative values found, no rescaling needed.
# Venezuela
# No negative values found, no rescaling needed.
# Guyana
# No negative values found, no rescaling needed.
# Suriname
# No negative values found, no rescaling needed.
# France
# No negative values found, no rescaling needed.
# Ecuador
# No negative values found, no rescaling needed.
# Calculation completed at 24%
# Puerto Rico
# No negative values found, no rescaling needed.
# Jamaica
# No negative values found, no rescaling needed.
# Cuba
# No negative values found, no rescaling needed.
# Zimbabwe
# No negative values found, no rescaling needed.
# Botswana
# No negative values found, no rescaling needed.
# Namibia
# No negative values found, no rescaling needed.
# Senegal
# No negative values found, no rescaling needed.
# Mali
# No negative values found, no rescaling needed.
# Mauritania
# No negative values found, no rescaling needed.
# Benin
# No negative values found, no rescaling needed.
# Niger
# No negative values found, no rescaling needed.
# Nigeria
# No negative values found, no rescaling needed.
# Cameroon
# No negative values found, no rescaling needed.
# Togo
# No negative values found, no rescaling needed.
# Ghana
# No negative values found, no rescaling needed.
# Côte d'Ivoire
# No negative values found, no rescaling needed.
# Guinea
# No negative values found, no rescaling needed.
# Guinea-Bissau
# No negative values found, no rescaling needed.
# Liberia
# No negative values found, no rescaling needed.
# Sierra Leone
# No negative values found, no rescaling needed.
# Burkina Faso
# No negative values found, no rescaling needed.
# Central African Rep.
# No negative values found, no rescaling needed.
# Congo
# No negative values found, no rescaling needed.
# Gabon
# No negative values found, no rescaling needed.
# Eq. Guinea
# No negative values found, no rescaling needed.
# Zambia
# No negative values found, no rescaling needed.
# Malawi
# No negative values found, no rescaling needed.
# Mozambique
# No negative values found, no rescaling needed.
# eSwatini
# No negative values found, no rescaling needed.
# Angola
# No negative values found, no rescaling needed.
# Burundi
# No negative values found, no rescaling needed.
# Israel
# No negative values found, no rescaling needed.
# Lebanon
# No negative values found, no rescaling needed.
# Madagascar
# No negative values found, no rescaling needed.
# Palestine
# No negative values found, no rescaling needed.
# Gambia
# No negative values found, no rescaling needed.
# Tunisia
# No negative values found, no rescaling needed.
# Algeria
# No negative values found, no rescaling needed.
# Jordan
# No negative values found, no rescaling needed.
# United Arab Emirates
# No negative values found, no rescaling needed.
# Qatar
# No negative values found, no rescaling needed.
# Kuwait
# No negative values found, no rescaling needed.
# Iraq
# No negative values found, no rescaling needed.
# Oman
# No negative values found, no rescaling needed.
# Calculation completed at 49%
# Vanuatu
# No negative values found, no rescaling needed.
# Cambodia
# No negative values found, no rescaling needed.
# Thailand
# No negative values found, no rescaling needed.
# Laos
# No negative values found, no rescaling needed.
# Myanmar
# No negative values found, no rescaling needed.
# Vietnam
# No negative values found, no rescaling needed.
# North Korea
# No negative values found, no rescaling needed.
# South Korea
# No negative values found, no rescaling needed.
# Mongolia
# No negative values found, no rescaling needed.
# India
# No negative values found, no rescaling needed.
# Bangladesh
# No negative values found, no rescaling needed.
# Bhutan
# No negative values found, no rescaling needed.
# Nepal
# No negative values found, no rescaling needed.
# Pakistan
# No negative values found, no rescaling needed.
# Afghanistan
# No negative values found, no rescaling needed.
# Tajikistan
# No negative values found, no rescaling needed.
# Kyrgyzstan
# No negative values found, no rescaling needed.
# Turkmenistan
# No negative values found, no rescaling needed.
# Iran
# No negative values found, no rescaling needed.
# Syria
# No negative values found, no rescaling needed.
# Armenia
# No negative values found, no rescaling needed.
# Sweden
# No negative values found, no rescaling needed.
# Belarus
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 61.69%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -15.42%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 36.88%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -9.22%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 24.34%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -6.08%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 16.82%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -4.21%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 11.94%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.99%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 8.63%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.16%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 6.3%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.58%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.64%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.16%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.44%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.86%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.55%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.64%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.9%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.4%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Ukraine
# No negative values found, no rescaling needed.
# Poland
# No negative values found, no rescaling needed.
# Austria
# No negative values found, no rescaling needed.
# Hungary
# No negative values found, no rescaling needed.
# Moldova
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 157.74%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -25.0%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 93.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -23.38%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 48.5%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -12.12%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 30.6%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -7.65%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 20.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -5.17%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 14.49%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -3.62%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 10.38%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -2.59%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 7.54%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.88%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 5.53%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.38%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 4.08%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -1.02%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 3.03%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.76%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 2.26%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.56%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.68%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# The timeseries are miss-aligned at the transition year by more than 1%.
# Current miss-alignement is: 1.18%
# To achieve a smooth transition, we re-apply the min-max rescaling with maximum value adjusted -0.5%
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Romania
# No negative values found, no rescaling needed.
# Lithuania
# No negative values found, no rescaling needed.
# Latvia
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Estonia
# No negative values found, no rescaling needed.
# Germany
# No negative values found, no rescaling needed.
# Bulgaria
# No negative values found, no rescaling needed.
# Greece
# No negative values found, no rescaling needed.
# Turkey
# No negative values found, no rescaling needed.
# Albania
# No negative values found, no rescaling needed.
# Croatia
# No negative values found, no rescaling needed.
# Switzerland
# No negative values found, no rescaling needed.
# Luxembourg
# No negative values found, no rescaling needed.
# Belgium
# No negative values found, no rescaling needed.
# Netherlands
# No negative values found, no rescaling needed.
# Portugal
# No negative values found, no rescaling needed.
# Spain
# No negative values found, no rescaling needed.
# Calculation completed at 74%
# Ireland
# No negative values found, no rescaling needed.
# New Caledonia
# Negative values found, iterative rescaling applied.
# Historical middle point is zero, skipping this country.
# Solomon Is.
# No negative values found, no rescaling needed.
# New Zealand
# No negative values found, no rescaling needed.
# Australia
# No negative values found, no rescaling needed.
# Sri Lanka
# No negative values found, no rescaling needed.
# China
# No negative values found, no rescaling needed.
# Taiwan
# No negative values found, no rescaling needed.
# Italy
# No negative values found, no rescaling needed.
# Denmark
# No negative values found, no rescaling needed.
# United Kingdom
# No negative values found, no rescaling needed.
# Iceland
# No negative values found, no rescaling needed.
# Azerbaijan
# No negative values found, no rescaling needed.
# Georgia
# No negative values found, no rescaling needed.
# Philippines
# No negative values found, no rescaling needed.
# Malaysia
# No negative values found, no rescaling needed.
# Brunei
# No negative values found, no rescaling needed.
# Slovenia
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Finland
# No negative values found, no rescaling needed.
# Slovakia
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Czechia
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Eritrea
# No negative values found, no rescaling needed.
# Japan
# No negative values found, no rescaling needed.
# Paraguay
# No negative values found, no rescaling needed.
# Yemen
# No negative values found, no rescaling needed.
# Saudi Arabia
# No negative values found, no rescaling needed.
# Antarctica
# No negative values found, no rescaling needed.
# N. Cyprus
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Cyprus
# Negative values found, iterative rescaling applied.
# Succesful correction of negative values while preserving trends has been completed.
# Morocco
# No negative values found, no rescaling needed.
# Egypt
# No negative values found, no rescaling needed.
# Libya
# No negative values found, no rescaling needed.
# Ethiopia
# No negative values found, no rescaling needed.
# Djibouti
# No negative values found, no rescaling needed.
# Somaliland
# No negative values found, no rescaling needed.
# Uganda
# No negative values found, no rescaling needed.
# Rwanda
# No negative values found, no rescaling needed.
# Bosnia and Herz.
# No negative values found, no rescaling needed.
# North Macedonia
# No negative values found, no rescaling needed.
# Serbia
# No negative values found, no rescaling needed.
# Montenegro
# No negative values found, no rescaling needed.
# Kosovo
# No negative values found, no rescaling needed.
# Trinidad and Tobago
# No negative values found, no rescaling needed.
# S. Sudan
# No negative values found, no rescaling needed.
# Calculation completed at 98%
# No correction applied to gridcells outside the regionmask country boundaries (country code 177).
# Future countries and US states timeseries are corrected. The updated values can be found in the provided input xarray.DataArray's.

# %% [markdown]
# ## Plot corrected national and US states timeseries:

# %%
plot_countries_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/country_level/", hist_countries_timeseries, future_countries_timeseries, corrected_future_countries_timeseries, "Livestock", countries_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/country_level/ directory.

# %%
plot_US_states_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/US_state_level", hist_US_states_timeseries, future_US_states_timeseries, corrected_future_US_states_timeseries, "Livestock", states_names)
# Out:
# All plots have been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/US_state_level directory.

# %% [markdown]
# ## Plot orriginal and corrected global water withdrawal time-series:

# %%
plot_global_monthly_timeseries_with_future_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level", hist_countries_timeseries, future_countries_timeseries, corrected_future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, corrected_future_US_states_timeseries, "Livestock", countries_names, states_names)
# Out:
# Global plot has been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level directory.

# %%
plot_global_monthly_timeseries_no_correction("/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level", hist_countries_timeseries, future_countries_timeseries, hist_US_states_timeseries, future_US_states_timeseries, "Livestock", countries_names, states_names)
# Out:
# Global plot has been created. You can check the results in the /vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/timeseries_after_correction/global_level directory.

# %% [markdown]
# ## Visually inspect corrected national, US states and global timeseries:
#
# Through visual inspection we can confirm a perfect harmonization between the past and future datasets.

# %% [markdown]
# # Check for any negative values

# %%
# Check for negative values in corrected_future_countries_timeseries
check_negative_values(corrected_future_countries_timeseries, countries_names, entity_type="country")

# Check for negative values in corrected_future_US_states_timeseries
check_negative_values(corrected_future_US_states_timeseries, states_names, entity_type="US_states")
# Out:
# Negative values found in New Caledonia
# No negative values found in Us_states dataset.

# %% [markdown]
# # Save the time-series as .csv files

# %%
import xarray as xr
import pandas as pd

# Assuming the following DataArrays are already defined:
# hist_countries_timeseries: xarray.DataArray with dims (country: 178, time: 480)
# corrected_future_countries_timeseries: xarray.DataArray with dims (country: 178, time: 1092)
# countries_names: dictionary mapping indices to country names

# Concatenate the historical and future time-series along the time dimension
combined_timeseries = xr.concat([hist_countries_timeseries, corrected_future_countries_timeseries], dim='time')

# Loop over each country and save the corresponding time-series to a CSV file
for country_index in range(len(countries_names)):
    # Extract the data for the current country
    country_data = combined_timeseries.sel(country=country_index)
    
    # Convert to DataFrame
    country_df = country_data.to_dataframe(name='value').reset_index()
    
    # Map the country index to its name
    country_name = countries_names[country_index]
    country_df['country'] = country_name
    
    # Save to CSV with the country name as the filename
    filename = "./csv_files_of_countries_and_us_states_timeseries/livestock_" + f"{country_name}_timeseries.csv"
    country_df.to_csv(filename, index=False)
    
    print(f"Saved {filename}")
# Out:
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Fiji_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Tanzania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_W. Sahara_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Canada_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_United States of America_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kazakhstan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Uzbekistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Papua New Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Indonesia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Argentina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Chile_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Dem. Rep. Congo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Somalia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kenya_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Sudan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Chad_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Haiti_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Dominican Rep._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Russia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Bahamas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Falkland Is._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Norway_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Greenland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Fr. S. Antarctic Lands_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Timor-Leste_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_South Africa_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Lesotho_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Mexico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Uruguay_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Brazil_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Bolivia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Peru_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Colombia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Panama_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Costa Rica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Nicaragua_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Honduras_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_El Salvador_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Guatemala_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Belize_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Venezuela_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Guyana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Suriname_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_France_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Ecuador_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Puerto Rico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Jamaica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Cuba_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Zimbabwe_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Botswana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Namibia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Senegal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Mali_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Mauritania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Benin_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Niger_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Nigeria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Cameroon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Togo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Ghana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Côte d'Ivoire_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Guinea-Bissau_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Liberia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Sierra Leone_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Burkina Faso_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Central African Rep._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Congo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Gabon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Eq. Guinea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Zambia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Malawi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Mozambique_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_eSwatini_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Angola_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Burundi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Israel_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Lebanon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Madagascar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Palestine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Gambia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Tunisia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Algeria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Jordan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_United Arab Emirates_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Qatar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kuwait_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Iraq_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Oman_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Vanuatu_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Cambodia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Thailand_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Laos_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Myanmar_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Vietnam_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_North Korea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_South Korea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Mongolia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_India_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Bangladesh_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Bhutan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Nepal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Pakistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Afghanistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Tajikistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kyrgyzstan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Turkmenistan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Iran_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Syria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Armenia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Sweden_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Belarus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Ukraine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Poland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Austria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Hungary_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Moldova_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Romania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Lithuania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Latvia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Estonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Germany_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Bulgaria_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Greece_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Turkey_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Albania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Croatia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Switzerland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Luxembourg_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Belgium_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Netherlands_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Portugal_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Spain_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Ireland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_New Caledonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Solomon Is._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_New Zealand_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Australia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Sri Lanka_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_China_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Taiwan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Italy_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Denmark_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_United Kingdom_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Iceland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Azerbaijan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Georgia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Philippines_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Malaysia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Brunei_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Slovenia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Finland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Slovakia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Czechia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Eritrea_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Japan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Paraguay_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Yemen_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Saudi Arabia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Antarctica_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_N. Cyprus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Cyprus_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Morocco_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Egypt_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Libya_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Ethiopia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Djibouti_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Somaliland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Uganda_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Rwanda_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Bosnia and Herz._timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_North Macedonia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Serbia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Montenegro_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kosovo_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Trinidad and Tobago_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_S. Sudan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Not a regionmask country_timeseries.csv

# %%
import xarray as xr
import pandas as pd

# Assuming the following DataArrays are already defined:
# hist_US_states_timeseries: xarray.DataArray with dims (state: N, time: 480)
# corrected_future_US_states_timeseries: xarray.DataArray with dims (state: N, time: 1092)
# states_names: dictionary mapping indices to state names

# Concatenate the historical and future time-series along the time dimension
combined_timeseries = xr.concat([hist_US_states_timeseries, corrected_future_US_states_timeseries], dim='time')

# Loop over each state and save the corresponding time-series to a CSV file
for state_index in range(len(states_names)):
    # Extract the data for the current state
    state_data = combined_timeseries.sel(US_states=state_index)
    
    # Convert to DataFrame
    state_df = state_data.to_dataframe(name='value').reset_index()
    
    # Map the state index to its name
    state_name = states_names[state_index]
    state_df['US_states'] = state_name
    
    # Save to CSV with the state name as the filename
    filename = "./csv_files_of_countries_and_us_states_timeseries/livestock_" + f"{state_name}_timeseries.csv"
    state_df.to_csv(filename, index=False)
    
    print(f"Saved {filename}")
# Out:
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Alaska_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Alabama_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Arkansas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Arizona_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_California_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Colorado_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Connecticut_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_District of Columbia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Delaware_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Florida_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Georgia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Hawaii_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Iowa_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Idaho_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Illinois_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Indiana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kansas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Kentucky_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Louisiana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Massachusetts_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Maryland_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Maine_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Michigan_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Minnesota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Missouri_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Mississippi_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Montana_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_North Carolina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_North Dakota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Nebraska_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_New Hampshire_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_New Jersey_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_New Mexico_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Nevada_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_New York_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Ohio_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Oklahoma_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Oregon_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Pennsylvania_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Rhode Island_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_South Carolina_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_South Dakota_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Tennessee_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Texas_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Utah_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Virginia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Vermont_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Washington_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Wisconsin_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_West Virginia_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Wyoming_timeseries.csv
# Saved ./csv_files_of_countries_and_us_states_timeseries/livestock_Not a regionmask state_timeseries.csv

# %% [markdown]
# # Downscale the national and US states data

# %% [markdown]
# After correcting the time-series at natioanal level, we should update the individual gridcells values accordingly. To do so, we apply the same gridcells weights as in the original future water use dataset to perform the spatial downscaling of the new national time series.

# %%
path_to_save_corrected_gridded_data = "/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/livestock"
downscale_future_corrected_national_and_US_states_timeseries_to_gridded_format_and_save_it(future_gridded_data, path_to_save_corrected_gridded_data, mask_countries, states_indices, mask_US_states, countries_indices, corrected_future_countries_timeseries, corrected_future_US_states_timeseries, "total_withdrawal_livestock", "twdliv")
# Out:
# Year completed: 2010
# Year completed: 2020
# Year completed: 2030
# Year completed: 2040
# Year completed: 2050
# Year completed: 2060
# Year completed: 2070
# Year completed: 2080
# Year completed: 2090
# Year completed: 2100
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2010.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2011.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2012.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2013.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2014.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2015.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2016.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2017.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2018.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2019.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2020.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2021.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2022.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2023.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2024.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2025.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2026.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2027.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2028.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2029.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2030.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2031.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2032.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2033.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2034.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2035.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2036.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2037.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2038.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2039.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2040.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2041.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2042.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2043.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2044.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2045.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2046.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2047.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2048.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2049.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2050.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2051.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2052.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2053.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2054.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2055.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2056.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2057.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2058.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2059.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2060.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2061.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2062.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2063.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2064.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2065.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2066.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2067.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2068.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2069.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2070.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2071.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2072.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2073.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2074.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2075.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2076.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2077.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2078.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2079.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2080.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2081.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2082.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2083.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2084.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2085.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2086.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2087.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2088.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2089.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2090.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2091.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2092.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2093.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2094.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2095.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2096.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2097.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2098.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2099.nc
# Saved twdliv_m3_per_day_with_corrected_national_time_series_2100.nc

# %% [markdown]
# # Plot the spatial consistency:

# %%
# Historical data processing
historical_directory = '/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand/processed/yearly_format/livestock/'
historical_pattern = 'withdrawal_livestock_m3_per_day_'
historical_data = process_files_annual_average(historical_directory, historical_pattern)

# Future data processing
future_directory = '/user/brussel/105/vsc10535/our_vo/SocioHydroLayers/input/sector_demand_future/ssp2_rcp26_gfdl/other_sectors/nc_format/yearly_format/livestock/'
future_pattern = 'twdliv_m3_per_day_2'
future_data = process_files_annual_average(future_directory, future_pattern)

# Corrected future data processing
corrected_future_pattern = 'twdliv_m3_per_day_with_corrected_national_time_series_'
corrected_future_data = process_files_annual_average(future_directory, corrected_future_pattern)
# Out:
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.
# A xarray.Dataset corresponding to the annualy aggregated data in the given path was succesfully generated.

# %%
def plot_water_withdrawal_changes(historical_data, original_future_data, corrected_future_data, variable_name_hist, variable_name_future, variable_name_for_the_title, path_save_plot):
    map_proj = ccrs.Robinson(central_longitude=0)
    
    # Create a figure with 1 row and 2 columns
    fig, axes = plt.subplots(1, 2, figsize=(20, 10), subplot_kw={'projection': map_proj})
    
    # First figure: Change for 2010/2011 with the original data
    ax1 = axes[0]
    ww_2010 = historical_data.sel(time='2010')[variable_name_hist][0]
    ww_2011_original = original_future_data.sel(time='2011')[variable_name_future][0]
    delta_original = (ww_2011_original - ww_2010) / ww_2010 * 100
    
    ax1.axis('off')
    ax1.coastlines(color='lightgray', linewidth=0.5)
    delta_original.plot(ax=ax1, cbar_kwargs={'fraction': 0.02, 'pad': 0.04, 'extend': 'both'}, cmap='RdBu', vmin=-100, vmax=100, transform=ccrs.PlateCarree(), add_colorbar=True, add_labels=False)
    ax1.set_title(f'$\Delta$ {variable_name_for_the_title} 2010-2011 (Original) (%)', loc='right', fontsize=20)
    
    # Second figure: Change for 2010/2011 with the corrected data
    ax2 = axes[1]
    ww_2011_corrected = corrected_future_data.sel(time='2011')[variable_name_future][0]
    delta_corrected = (ww_2011_corrected - ww_2010) / ww_2010 * 100
    
    ax2.axis('off')
    ax2.coastlines(color='lightgray', linewidth=0.5)
    delta_corrected.plot(ax=ax2, cbar_kwargs={'fraction': 0.02, 'pad': 0.04, 'extend': 'both'}, cmap='RdBu', vmin=-100, vmax=100, transform=ccrs.PlateCarree(), add_colorbar=True, add_labels=False)
    ax2.set_title(f'$\Delta$ {variable_name_for_the_title} 2010-2011 (Corrected) (%)', loc='right', fontsize=20)
    
    fig.tight_layout()
    plt.savefig(path_save_plot, format='pdf')

# %%
path_save_plot = "/vscmnt/brussel_pixiu_data/_data_brussel/105/vsc10535/SocioHydroLayers/source/sector_demand_data_harmonization/Final_data_harmonization_codebase_ssp2_rcp26_gfdl/plots/spatial_consistency_maps/relative_change_in_livestock_water_withdrawal_original.pdf"
plot_water_withdrawal_changes(historical_data, future_data, corrected_future_data, "withd_liv", "total_withdrawal_livestock", "Livestock Withdrawal", path_save_plot)
